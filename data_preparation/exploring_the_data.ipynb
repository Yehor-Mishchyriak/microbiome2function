# %%
from uniprot_parsing import data_from_Uniref90ID, FIELDS

# %%
df = data_from_Uniref90ID("A0A1B0GTW7", *FIELDS)
# Out:
# Querying fields for A0A1B0GTW7: 100%|███████████| 13/13 [00:04<00:00,  2.70it/s]

# %%
df
# Out:
# {'cc_function': {'0.entryType': 'UniProtKB reviewed (Swiss-Prot)',
#   '0.primaryAccession': 'A0A1B0GTW7',
#   '0.comments.0.texts.0.evidences.0.evidenceCode': 'ECO:0000250',
#   '0.comments.0.texts.0.evidences.0.source': 'UniProtKB',
#   '0.comments.0.texts.0.evidences.0.id': 'A0A1D5NSK0',
#   '0.comments.0.texts.0.value': 'Putative metalloproteinase that plays a role in left-right patterning process',
#   '0.comments.0.commentType': 'FUNCTION',
#   '0.extraAttributes.uniParcId': 'UPI0007E52C07'},
#  'cc_catalytic_activity': {'0.entryType': 'UniProtKB reviewed (Swiss-Prot)',
#   '0.primaryAccession': 'A0A1B0GTW7',
#   '0.extraAttributes.uniParcId': 'UPI0007E52C07'},
#  'ec': {'0.entryType': 'UniProtKB reviewed (Swiss-Prot)',
#   '0.primaryAccession': 'A0A1B0GTW7',
#   '0.proteinDescription.recommendedName.fullName.evidences.0.evidenceCode': 'ECO:0000303',
#   '0.proteinDescription.recommendedName.fullName.evidences.0.source': 'PubMed',
# ...

# %%
FIELDS
# Out:
# ['cc_function',
#  'cc_catalytic_activity',
#  'ec',
#  'cc_pathway',
#  'rhea',
#  'cc_cofactor',
#  'cc_activity_regulation',
#  'cc_interaction',
#  'go_f',
#  'go_p',
#  'ft_domain',
#  'cc_domain',
#  'protein_families']

# %%
df["cc_function"]
# Out:
# {'0.entryType': 'UniProtKB reviewed (Swiss-Prot)',
#  '0.primaryAccession': 'A0A1B0GTW7',
#  '0.comments.0.texts.0.evidences.0.evidenceCode': 'ECO:0000250',
#  '0.comments.0.texts.0.evidences.0.source': 'UniProtKB',
#  '0.comments.0.texts.0.evidences.0.id': 'A0A1D5NSK0',
#  '0.comments.0.texts.0.value': 'Putative metalloproteinase that plays a role in left-right patterning process',
#  '0.comments.0.commentType': 'FUNCTION',
#  '0.extraAttributes.uniParcId': 'UPI0007E52C07'}
