# %%
# %cd ..
# Out:
# /Users/yehormishchyriak/Desktop/BonhamLab/summer2025/microbiome2function/dataset_curation

# %%
import pandas as pd
import scripts

# %%
# ENV
from os import getenv
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # Single full file

# %%
gene_fam_data = getenv("RAW_DATA")

# %%
unirefs, _ = scripts.ids_from_tsv(gene_fam_data) # note: used "_" because UniClust IDs were also returned

# %%
df = scripts.retrieve_fields_for_unirefs(unirefs, fields=scripts.recommended_fields_example2)

# %%
df

# %% [markdown]
# # Multiple files (snippets -- as an example)

# %%
scripts.configure_logging(logs_dir=getenv("LOGS_DIR"))

# %%
dir_ = getenv("RAW_DATA_FILES")

# %%
ids = scripts.unirefs_from_multiple_files(dir_)

# %%
ids
# Out:
# ['A0A173U7U4',
#  'A0A173SR92',
#  'A7B1P5',
#  'A0A069RJB6',
#  'D7GTN1',
#  'C4ZDX9',
#  'A0A174QXS4',
#  'A0A416QK53',
#  'D6DFQ9',
#  'A0A192CDZ5',
#  'J7TG29',
#  'A0A174I5P4',
#  'A0A174HW30',
#  'I8ZNQ1',
#  'A0A396ABH4',
#  'R9IFF8',
#  'K1V5J3']

# %%
pd.set_option("future.no_silent_downcasting", True)

# %%
scripts.process_uniref_batches(ids, fields=scripts.recommended_fields_example2, batch_size=2,
                               save_to_dir=None)
# Out:
# 2025-07-25 18:09:39,275 [WARNING] scripts.mining_utils: save_to_dir is set to None! Repsonse to the API request #1 will discarded
# 2025-07-25 18:09:39,843 [WARNING] scripts.mining_utils: save_to_dir is set to None! Repsonse to the API request #2 will discarded
# 2025-07-25 18:09:40,440 [WARNING] scripts.mining_utils: save_to_dir is set to None! Repsonse to the API request #3 will discarded
# 2025-07-25 18:09:41,073 [WARNING] scripts.mining_utils: save_to_dir is set to None! Repsonse to the API request #4 will discarded
# 2025-07-25 18:09:41,611 [WARNING] scripts.mining_utils: save_to_dir is set to None! Repsonse to the API request #5 will discarded
# 2025-07-25 18:09:42,157 [WARNING] scripts.mining_utils: save_to_dir is set to None! Repsonse to the API request #6 will discarded
# 2025-07-25 18:09:42,783 [WARNING] scripts.mining_utils: save_to_dir is set to None! Repsonse to the API request #7 will discarded
# 2025-07-25 18:09:43,323 [WARNING] scripts.mining_utils: save_to_dir is set to None! Repsonse to the API request #8 will discarded
# 2025-07-25 18:09:43,892 [WARNING] scripts.mining_utils: save_to_dir is set to None! Repsonse to the API request #9 will discarded

# %% [markdown]
# ### As you can see ^^^ logging works :)

# %%
# no warnings here
scripts.process_uniref_batches(ids, fields=scripts.recommended_fields_example2, batch_size=2,
                               save_to_dir="/Users/yehormishchyriak/Desktop/BonhamLab/summer2025/microbiome2function/untracked_data/dummy_response_sequence")
